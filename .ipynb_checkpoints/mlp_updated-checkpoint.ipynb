# %%
#%pip install keras tensorflow
#Dataset transform: We change parameters with the Illinois dataset.
#Future selection showed that Precipitation, Temperature max and min and Solar radiation are the factors that significantly impact the yield.
# With Adaptive optimizer (ADAM)
#1. Normal dataset: Y=0.75, Yhat= 0.782, MAE = 0.01040  ########################## Y=0.78272 , Yhat=0.865  , MAE= 0.01288
#2. We changed the Solar radiation: Y=0.75, Yhat = 0.756, MAE= 0.01886  ########################## Y=0.78272 ,Yhat= 0.800  , MAE= 0.01726 
#3. We changed the Precipitation: Y=0.75, Yhat = 0.760 , MAE= 0.01995   ########################## Y=0.78272 ,Yhat= 0.807 , MAE= 0.01474
#4. We changed the Min_Temperature: Y=0.75, Yhat = 0.757 , MAE= 0.01677 ########################## Y=0.78272 ,Yhat= 0.791 , MAE=0.01285
#5. We changed the Max_Temperature: Y=0.75, Yhat = 0.752, MAE= 0.01648  ########################## Y=0.78272 ,Yhat= 0.812 , MAE=0.01699 
#6. We changed All the 4 parameters: Y=0.75, Yhat = 0.772 , MAE= 0.01538 ########################## Y=0.78272 ,Yhat= 0.820 , MAE= 0.01382

# With Stochastic Gradient Descent (SGD)
#1. Normal dataset: Y=0.75, Yhat= 0.791, MAE = 0.01564 ########################## Y=0.78272 ,Yhat= 0.896 , MAE= 0.01915
#2. We changed the Solar radiation: Y=0.75, Yhat = 0.772, MAE= 0.02294 ########################## Y=0.78272, Yhat=0.793, MAE=0.02420
#3. We changed the Precipitation: Y=0.75, Yhat = 0.794 , MAE= 0.01483 ########################## Y=0.78272, Yhat=0.821, MAE=0.01723
#4. We changed the Min_Temperature: Y=0.75, Yhat = 0.771 , MAE= 0.01459 ########################## Y=0.78272 ,Yhat= 0.813 , MAE= 0.01605
#5. We changed the Max_Temperature: Y=0.75, Yhat = 0.776, MAE= 0.01629  ########################## Y=0.78272 ,Yhat= 0.826 , MAE= 0.01634
#6. We changed All the 4 parameters: Y=0.75, Yhat = 0.797, MAE= 0.01988 ########################## Y=0.78272 ,Yhat= 0.888 , MAE=

# %%
#%pip install scikeras

# %%
# first neural network with keras tutorial
import tensorflow as tf
from tensorflow import keras
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
#from keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from numpy import asarray
from numpy import unique
from numpy import argmax
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from keras.utils.vis_utils import plot_model
from sklearn.preprocessing import StandardScaler

# %%
# load the dataset
dataset = loadtxt('Dataset_transformAll.csv', delimiter=',') #('datas.csv', delimiter=',') #('Audrey_Dataset.csv', delimiter=',')
# split into input (X) and output (y) variables
#X = dataset[:,0:7]
#y = dataset[:,7]

# %%
###############################################################################################
#Dataset transform: We change parameters with the Illinois dataset.
#Future selection showed that Precipitation, Temperature max and min and Solar radiation are the factors that significantly impact the yield.
#1. Normal dataset: Y=0.75, Yhat= 0.774, MAE = 0.00901
#2. We changed the Solar radiation: Y=0.75, Yhat = 0.785, MAE= 0.01315
#3. We changed the Precipitation: Y=0.75, Yhat = 0.788 , MAE= 0.01014
#4. We changed the Min_Temperature: Y=0.75, Yhat = 0.773 , MAE= 0.01182
#5. We changed the Max_Temperature: Y=0.75, Yhat = 0.763 , MAE= 0.02105
#6. We changed All the 4 parameters: Y=0.75, Yhat = 0.771 , MAE= 0.01477
###############################################################################################

# %%
# # #ESSAI 3  -----OK
# X = dataset[:,0:7]
# y = dataset[:,7]
# scalarX, scalarY = MinMaxScaler(feature_range=(0,75)), MinMaxScaler(feature_range=(0,0.75))
# scalarX.fit(X)
# scalarY.fit(y.reshape(213,1))
# X = scalarX.transform(X)
# y=np.array(y).reshape(213,1)
# y = scalarY.transform(y) #.reshape(213,1))

# %%
# #ESSAI 3  -----OK
X = dataset[:,0:7]
y = dataset[:,7]
scalarX, scalarY = MinMaxScaler(feature_range=(0,1)), MinMaxScaler(feature_range=(0,0.75))
scalarX.fit(X)
scalarY.fit(y.reshape(94,1)) 
X = scalarX.transform(X)
y=np.array(y).reshape(94,1) 
y = scalarY.transform(y)

# %%
print(y)
# Out:
# [[0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [5.71983935e-04]
#  [2.18923901e-03]
#  [4.74422103e-03]
#  [8.22762667e-03]
#  [1.23189629e-02]
#  [1.77387289e-02]
#  [2.42075523e-02]
#  [3.08176139e-02]
#  [3.95917972e-02]
#  [4.92520136e-02]
#  [5.97893942e-02]
#  [7.09169107e-02]
#  [8.20202916e-02]
#  [9.18582411e-02]
#  [1.02595174e-01]
#  [1.13708303e-01]
#  [1.27787857e-01]
#  [1.44147250e-01]
#  [1.61351537e-01]
#  [1.82024197e-01]
#  [2.03626676e-01]
#  [2.23773302e-01]
#  [2.42121629e-01]
#  [2.61462524e-01]
#  [2.83741332e-01]
#  [3.08130991e-01]
#  [3.32849942e-01]
#  [3.57598221e-01]
#  [3.81505202e-01]
#  [4.10808924e-01]
#  [4.36042928e-01]
#  [4.65689622e-01]
#  [4.94960919e-01]
#  [5.28935958e-01]
#  [5.35587435e-01]
#  [5.49707126e-01]
#  [5.67077886e-01]
#  [5.83964416e-01]
#  [5.92958436e-01]
#  [6.03276245e-01]
#  [6.13848251e-01]
#  [6.24868091e-01]
#  [6.42382335e-01]
#  [6.61105999e-01]
#  [6.74930273e-01]
#  [6.82905842e-01]
#  [6.94466083e-01]
#  [7.08957685e-01]
#  [7.24161220e-01]
#  [7.37046700e-01]
#  [7.50000000e-01]
#  [7.50000000e-01]]

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=7, kernel_initializer='normal', activation='relu')) #kernel_initializer='normal'
model.add(Dense(1, kernel_initializer='normal', activation='linear')) #linear
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 20)                160
#
#  dense_5 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#sgd = tf.keras.optimizers.SGD(learning_rate=0.01, decay=0.0, momentum=0.7, nesterov=False)
adam=tf.keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
model.compile(optimizer=adam, loss='mean_absolute_error')

# %%
# fit the keras model on the dataset
history = model.fit(X, y, epochs=100, batch_size=4, verbose=2, validation_split=0.20)
# Out:
# Epoch 1/100
# 19/19 - 0s - loss: 0.0761 - val_loss: 0.5791 - 418ms/epoch - 22ms/step
# Epoch 2/100
# 19/19 - 0s - loss: 0.0705 - val_loss: 0.5362 - 84ms/epoch - 4ms/step
# Epoch 3/100
# 19/19 - 0s - loss: 0.0622 - val_loss: 0.4206 - 56ms/epoch - 3ms/step
# Epoch 4/100
# 19/19 - 0s - loss: 0.0593 - val_loss: 0.4621 - 58ms/epoch - 3ms/step
# Epoch 5/100
# 19/19 - 0s - loss: 0.0497 - val_loss: 0.3517 - 58ms/epoch - 3ms/step
# Epoch 6/100
# 19/19 - 0s - loss: 0.0436 - val_loss: 0.2979 - 57ms/epoch - 3ms/step
# Epoch 7/100
# 19/19 - 0s - loss: 0.0349 - val_loss: 0.2600 - 60ms/epoch - 3ms/step
# Epoch 8/100
# 19/19 - 0s - loss: 0.0321 - val_loss: 0.2620 - 55ms/epoch - 3ms/step
# Epoch 9/100
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.1682 - 65ms/epoch - 3ms/step
# Epoch 10/100
# 19/19 - 0s - loss: 0.0340 - val_loss: 0.1636 - 59ms/epoch - 3ms/step
# Epoch 11/100
# 19/19 - 0s - loss: 0.0327 - val_loss: 0.2190 - 71ms/epoch - 4ms/step
# Epoch 12/100
# 19/19 - 0s - loss: 0.0282 - val_loss: 0.0785 - 58ms/epoch - 3ms/step
# Epoch 13/100
# 19/19 - 0s - loss: 0.0281 - val_loss: 0.1041 - 57ms/epoch - 3ms/step
# Epoch 14/100
# 19/19 - 0s - loss: 0.0289 - val_loss: 0.1355 - 64ms/epoch - 3ms/step
# Epoch 15/100
# 19/19 - 0s - loss: 0.0262 - val_loss: 0.1395 - 55ms/epoch - 3ms/step
# Epoch 16/100
# 19/19 - 0s - loss: 0.0270 - val_loss: 0.0787 - 59ms/epoch - 3ms/step
# Epoch 17/100
# 19/19 - 0s - loss: 0.0187 - val_loss: 0.1171 - 59ms/epoch - 3ms/step
# Epoch 18/100
# 19/19 - 0s - loss: 0.0184 - val_loss: 0.0700 - 56ms/epoch - 3ms/step
# Epoch 19/100
# 19/19 - 0s - loss: 0.0167 - val_loss: 0.0485 - 64ms/epoch - 3ms/step
# Epoch 20/100
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0559 - 57ms/epoch - 3ms/step
# Epoch 21/100
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0472 - 58ms/epoch - 3ms/step
# Epoch 22/100
# 19/19 - 0s - loss: 0.0125 - val_loss: 0.0598 - 57ms/epoch - 3ms/step
# Epoch 23/100
# 19/19 - 0s - loss: 0.0176 - val_loss: 0.0608 - 57ms/epoch - 3ms/step
# Epoch 24/100
# 19/19 - 0s - loss: 0.0122 - val_loss: 0.0511 - 57ms/epoch - 3ms/step
# Epoch 25/100
# 19/19 - 0s - loss: 0.0113 - val_loss: 0.0571 - 58ms/epoch - 3ms/step
# Epoch 26/100
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0524 - 60ms/epoch - 3ms/step
# Epoch 27/100
# 19/19 - 0s - loss: 0.0096 - val_loss: 0.0944 - 55ms/epoch - 3ms/step
# Epoch 28/100
# 19/19 - 0s - loss: 0.0102 - val_loss: 0.0675 - 64ms/epoch - 3ms/step
# Epoch 29/100
# 19/19 - 0s - loss: 0.0081 - val_loss: 0.0963 - 54ms/epoch - 3ms/step
# Epoch 30/100
# 19/19 - 0s - loss: 0.0105 - val_loss: 0.1075 - 57ms/epoch - 3ms/step
# Epoch 31/100
# 19/19 - 0s - loss: 0.0103 - val_loss: 0.1185 - 55ms/epoch - 3ms/step
# Epoch 32/100
# 19/19 - 0s - loss: 0.0154 - val_loss: 0.0673 - 57ms/epoch - 3ms/step
# Epoch 33/100
# 19/19 - 0s - loss: 0.0188 - val_loss: 0.0833 - 69ms/epoch - 4ms/step
# Epoch 34/100
# 19/19 - 0s - loss: 0.0212 - val_loss: 0.0701 - 56ms/epoch - 3ms/step
# Epoch 35/100
# 19/19 - 0s - loss: 0.0184 - val_loss: 0.2187 - 58ms/epoch - 3ms/step
# Epoch 36/100
# 19/19 - 0s - loss: 0.0257 - val_loss: 0.2239 - 57ms/epoch - 3ms/step
# Epoch 37/100
# 19/19 - 0s - loss: 0.0231 - val_loss: 0.1932 - 57ms/epoch - 3ms/step
# Epoch 38/100
# 19/19 - 0s - loss: 0.0266 - val_loss: 0.2063 - 60ms/epoch - 3ms/step
# Epoch 39/100
# 19/19 - 0s - loss: 0.0196 - val_loss: 0.1086 - 55ms/epoch - 3ms/step
# Epoch 40/100
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0821 - 61ms/epoch - 3ms/step
# Epoch 41/100
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0988 - 87ms/epoch - 5ms/step
# Epoch 42/100
# 19/19 - 0s - loss: 0.0247 - val_loss: 0.0545 - 67ms/epoch - 4ms/step
# Epoch 43/100
# 19/19 - 0s - loss: 0.0213 - val_loss: 0.0616 - 59ms/epoch - 3ms/step
# Epoch 44/100
# 19/19 - 0s - loss: 0.0098 - val_loss: 0.1201 - 58ms/epoch - 3ms/step
# Epoch 45/100
# 19/19 - 0s - loss: 0.0170 - val_loss: 0.0813 - 59ms/epoch - 3ms/step
# Epoch 46/100
# 19/19 - 0s - loss: 0.0156 - val_loss: 0.0701 - 69ms/epoch - 4ms/step
# Epoch 47/100
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.0777 - 58ms/epoch - 3ms/step
# Epoch 48/100
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.0974 - 56ms/epoch - 3ms/step
# Epoch 49/100
# 19/19 - 0s - loss: 0.0077 - val_loss: 0.0774 - 62ms/epoch - 3ms/step
# Epoch 50/100
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.1125 - 69ms/epoch - 4ms/step
# Epoch 51/100
# 19/19 - 0s - loss: 0.0086 - val_loss: 0.0893 - 58ms/epoch - 3ms/step
# Epoch 52/100
# 19/19 - 0s - loss: 0.0077 - val_loss: 0.1424 - 57ms/epoch - 3ms/step
# Epoch 53/100
# 19/19 - 0s - loss: 0.0075 - val_loss: 0.1310 - 54ms/epoch - 3ms/step
# Epoch 54/100
# 19/19 - 0s - loss: 0.0099 - val_loss: 0.1700 - 55ms/epoch - 3ms/step
# Epoch 55/100
# 19/19 - 0s - loss: 0.0164 - val_loss: 0.0946 - 63ms/epoch - 3ms/step
# Epoch 56/100
# 19/19 - 0s - loss: 0.0180 - val_loss: 0.0909 - 51ms/epoch - 3ms/step
# Epoch 57/100
# 19/19 - 0s - loss: 0.0119 - val_loss: 0.1018 - 53ms/epoch - 3ms/step
# Epoch 58/100
# 19/19 - 0s - loss: 0.0096 - val_loss: 0.1042 - 53ms/epoch - 3ms/step
# Epoch 59/100
# 19/19 - 0s - loss: 0.0093 - val_loss: 0.0928 - 60ms/epoch - 3ms/step
# Epoch 60/100
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.1210 - 54ms/epoch - 3ms/step
# Epoch 61/100
# 19/19 - 0s - loss: 0.0077 - val_loss: 0.1312 - 61ms/epoch - 3ms/step
# Epoch 62/100
# 19/19 - 0s - loss: 0.0081 - val_loss: 0.0913 - 61ms/epoch - 3ms/step
# Epoch 63/100
# 19/19 - 0s - loss: 0.0131 - val_loss: 0.1163 - 53ms/epoch - 3ms/step
# Epoch 64/100
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.1277 - 61ms/epoch - 3ms/step
# Epoch 65/100
# 19/19 - 0s - loss: 0.0111 - val_loss: 0.1361 - 54ms/epoch - 3ms/step
# Epoch 66/100
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.1110 - 64ms/epoch - 3ms/step
# Epoch 67/100
# 19/19 - 0s - loss: 0.0100 - val_loss: 0.1708 - 51ms/epoch - 3ms/step
# Epoch 68/100
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.1104 - 51ms/epoch - 3ms/step
# Epoch 69/100
# 19/19 - 0s - loss: 0.0088 - val_loss: 0.1288 - 53ms/epoch - 3ms/step
# Epoch 70/100
# 19/19 - 0s - loss: 0.0074 - val_loss: 0.1401 - 52ms/epoch - 3ms/step
# Epoch 71/100
# 19/19 - 0s - loss: 0.0104 - val_loss: 0.1012 - 62ms/epoch - 3ms/step
# Epoch 72/100
# 19/19 - 0s - loss: 0.0128 - val_loss: 0.1313 - 54ms/epoch - 3ms/step
# Epoch 73/100
# 19/19 - 0s - loss: 0.0101 - val_loss: 0.1000 - 66ms/epoch - 3ms/step
# Epoch 74/100
# 19/19 - 0s - loss: 0.0244 - val_loss: 0.1295 - 53ms/epoch - 3ms/step
# Epoch 75/100
# 19/19 - 0s - loss: 0.0109 - val_loss: 0.1059 - 51ms/epoch - 3ms/step
# Epoch 76/100
# 19/19 - 0s - loss: 0.0078 - val_loss: 0.1152 - 55ms/epoch - 3ms/step
# Epoch 77/100
# 19/19 - 0s - loss: 0.0070 - val_loss: 0.1022 - 61ms/epoch - 3ms/step
# Epoch 78/100
# 19/19 - 0s - loss: 0.0062 - val_loss: 0.1052 - 54ms/epoch - 3ms/step
# Epoch 79/100
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.1393 - 63ms/epoch - 3ms/step
# Epoch 80/100
# 19/19 - 0s - loss: 0.0134 - val_loss: 0.0954 - 49ms/epoch - 3ms/step
# Epoch 81/100
# 19/19 - 0s - loss: 0.0088 - val_loss: 0.1149 - 53ms/epoch - 3ms/step
# Epoch 82/100
# 19/19 - 0s - loss: 0.0063 - val_loss: 0.1258 - 51ms/epoch - 3ms/step
# Epoch 83/100
# 19/19 - 0s - loss: 0.0064 - val_loss: 0.1312 - 52ms/epoch - 3ms/step
# Epoch 84/100
# 19/19 - 0s - loss: 0.0088 - val_loss: 0.1255 - 62ms/epoch - 3ms/step
# Epoch 85/100
# 19/19 - 0s - loss: 0.0089 - val_loss: 0.1217 - 53ms/epoch - 3ms/step
# Epoch 86/100
# 19/19 - 0s - loss: 0.0097 - val_loss: 0.1544 - 62ms/epoch - 3ms/step
# Epoch 87/100
# 19/19 - 0s - loss: 0.0082 - val_loss: 0.2008 - 62ms/epoch - 3ms/step
# Epoch 88/100
# 19/19 - 0s - loss: 0.0115 - val_loss: 0.1461 - 54ms/epoch - 3ms/step
# Epoch 89/100
# 19/19 - 0s - loss: 0.0144 - val_loss: 0.1411 - 52ms/epoch - 3ms/step
# Epoch 90/100
# 19/19 - 0s - loss: 0.0139 - val_loss: 0.1255 - 51ms/epoch - 3ms/step
# Epoch 91/100
# 19/19 - 0s - loss: 0.0110 - val_loss: 0.1710 - 53ms/epoch - 3ms/step
# Epoch 92/100
# 19/19 - 0s - loss: 0.0112 - val_loss: 0.1014 - 54ms/epoch - 3ms/step
# Epoch 93/100
# 19/19 - 0s - loss: 0.0219 - val_loss: 0.1035 - 54ms/epoch - 3ms/step
# Epoch 94/100
# 19/19 - 0s - loss: 0.0092 - val_loss: 0.1408 - 53ms/epoch - 3ms/step
# Epoch 95/100
# 19/19 - 0s - loss: 0.0067 - val_loss: 0.1204 - 62ms/epoch - 3ms/step
# Epoch 96/100
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.1058 - 55ms/epoch - 3ms/step
# Epoch 97/100
# 19/19 - 0s - loss: 0.0092 - val_loss: 0.1502 - 53ms/epoch - 3ms/step
# Epoch 98/100
# 19/19 - 0s - loss: 0.0121 - val_loss: 0.1224 - 52ms/epoch - 3ms/step
# Epoch 99/100
# 19/19 - 0s - loss: 0.0103 - val_loss: 0.1409 - 54ms/epoch - 3ms/step
# Epoch 100/100
# 19/19 - 0s - loss: 0.0133 - val_loss: 0.2555 - 51ms/epoch - 3ms/step

# %%
# evaluate on test set
yhat = model.predict(X)
error = mean_absolute_error(y, yhat)
print('MAE: %.5f' % error)
# Out:
# MAE: 0.07243

# %%
print(yhat)
# Out:
# [[-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00211137]
#  [-0.00212643]
#  [-0.00207545]
#  [-0.00210538]
#  [-0.00215122]
#  [-0.00207545]
#  [-0.00217495]
#  [-0.00207545]
#  [-0.00217824]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [ 0.01124398]
#  [ 0.01481827]
#  [ 0.01831488]
#  [ 0.02905719]
#  [ 0.05010802]
#  [ 0.0470745 ]
#  [ 0.07390577]
#  [ 0.08621643]
#  [ 0.10944277]
#  [ 0.10930701]
#  [ 0.13250083]
#  [ 0.15951808]
#  [ 0.16726242]
#  [ 0.19325815]
#  [ 0.22095972]
#  [ 0.24283938]
#  [ 0.23741913]
#  [ 0.28796932]
#  [ 0.29633698]
#  [ 0.34990463]
#  [ 0.3663812 ]
#  [ 0.39726335]
#  [ 0.41320726]
#  [ 0.42161846]
#  [ 0.47234058]
#  [ 0.49370345]
#  [ 0.5142888 ]
#  [ 0.52291614]
#  [ 0.5380883 ]
#  [ 0.5967435 ]
#  [ 0.6251533 ]
#  [ 0.6522976 ]
#  [ 0.67260957]
#  [ 0.7396621 ]
#  [ 0.74807346]
#  [ 0.7340171 ]
#  [ 0.70492464]
#  [ 0.80789316]
#  [ 0.85939217]
#  [ 0.88280153]
#  [ 0.9475608 ]
#  [ 0.96845824]
#  [ 0.988677  ]
#  [ 1.054592  ]
#  [ 1.0724027 ]
#  [ 1.0914979 ]
#  [ 1.156508  ]
#  [ 1.1762613 ]
#  [ 1.1973245 ]]

# %%
print(y)
# Out:
# [[0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [5.71983935e-04]
#  [2.18923901e-03]
#  [4.74422103e-03]
#  [8.22762667e-03]
#  [1.23189629e-02]
#  [1.77387289e-02]
#  [2.42075523e-02]
#  [3.08176139e-02]
#  [3.95917972e-02]
#  [4.92520136e-02]
#  [5.97893942e-02]
#  [7.09169107e-02]
#  [8.20202916e-02]
#  [9.18582411e-02]
#  [1.02595174e-01]
#  [1.13708303e-01]
#  [1.27787857e-01]
#  [1.44147250e-01]
#  [1.61351537e-01]
#  [1.82024197e-01]
#  [2.03626676e-01]
#  [2.23773302e-01]
#  [2.42121629e-01]
#  [2.61462524e-01]
#  [2.83741332e-01]
#  [3.08130991e-01]
#  [3.32849942e-01]
#  [3.57598221e-01]
#  [3.81505202e-01]
#  [4.10808924e-01]
#  [4.36042928e-01]
#  [4.65689622e-01]
#  [4.94960919e-01]
#  [5.28935958e-01]
#  [5.35587435e-01]
#  [5.49707126e-01]
#  [5.67077886e-01]
#  [5.83964416e-01]
#  [5.92958436e-01]
#  [6.03276245e-01]
#  [6.13848251e-01]
#  [6.24868091e-01]
#  [6.42382335e-01]
#  [6.61105999e-01]
#  [6.74930273e-01]
#  [6.82905842e-01]
#  [6.94466083e-01]
#  [7.08957685e-01]
#  [7.24161220e-01]
#  [7.37046700e-01]
#  [7.50000000e-01]
#  [7.50000000e-01]]

# %%
plt.plot(y)

# %%
plt.plot(yhat)

# %%
print(yhat-y)
# Out:
# [[-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00211137]
#  [-0.00212643]
#  [-0.00207545]
#  [-0.00210538]
#  [-0.00215122]
#  [-0.00207545]
#  [-0.00217495]
#  [-0.00207545]
#  [-0.00217824]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00207545]
#  [-0.00264744]
#  [-0.00426469]
#  [-0.00681968]
#  [ 0.00301636]
#  [ 0.00249931]
#  [ 0.00057615]
#  [ 0.00484963]
#  [ 0.0192904 ]
#  [ 0.0074827 ]
#  [ 0.02465375]
#  [ 0.02642704]
#  [ 0.03852586]
#  [ 0.02728672]
#  [ 0.04064259]
#  [ 0.0569229 ]
#  [ 0.05355412]
#  [ 0.06547029]
#  [ 0.07681247]
#  [ 0.08148784]
#  [ 0.05539493]
#  [ 0.08434265]
#  [ 0.07256368]
#  [ 0.107783  ]
#  [ 0.10491867]
#  [ 0.11352202]
#  [ 0.10507627]
#  [ 0.08876852]
#  [ 0.11474236]
#  [ 0.11219825]
#  [ 0.10347986]
#  [ 0.08687321]
#  [ 0.0723987 ]
#  [ 0.1017826 ]
#  [ 0.09621734]
#  [ 0.11671018]
#  [ 0.12290244]
#  [ 0.17258422]
#  [ 0.16410904]
#  [ 0.14105864]
#  [ 0.1016484 ]
#  [ 0.19404491]
#  [ 0.23452407]
#  [ 0.2404192 ]
#  [ 0.28645479]
#  [ 0.29352796]
#  [ 0.30577118]
#  [ 0.36012593]
#  [ 0.36344503]
#  [ 0.36733668]
#  [ 0.41946127]
#  [ 0.42626131]
#  [ 0.44732451]]

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,101)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
