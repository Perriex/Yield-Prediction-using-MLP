# %%
# first neural network with keras tutorial
import tensorflow as tf
from tensorflow import keras
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
#from keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_regression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error
from numpy import asarray
from numpy import unique
from numpy import argmax
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from keras.utils.vis_utils import plot_model

# %%
# load the dataset
dataset = loadtxt('Dataset_transformAll.csv', delimiter=',')

# %%
#Plot the input 
X = dataset[:,0:7]
y = dataset[:,7]
plt.plot(X)
plt.xlabel('Time (Day)')
#plt.ylabel('Crop Yield')
plt.title('MLP Input values')
plt.show()

# %%
# #ESSAI 3  -----OK
X = dataset[:,0:7]
y = dataset[:,7]
scalarX, scalarY = MinMaxScaler(feature_range=(0,1)), MinMaxScaler(feature_range=(0,0.78272))
scalarX.fit(X)
scalarY.fit(y.reshape(94,1)) 
X = scalarX.transform(X)
y=np.array(y).reshape(94,1) 
y = scalarY.transform(y)

# %%
#print(y)

# %%
#Plot the Normalized input
plt.plot(X)
plt.xlabel('Time (Day)')
#plt.ylabel('Crop Yield')
plt.title('MLP Normalized Input Values')
plt.show()

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=7, kernel_initializer='normal', activation='relu')) #kernel_initializer='normal'
model.add(Dense(1, kernel_initializer='normal', activation='linear')) #linear
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 20)                160
#
#  dense_11 (Dense)            (None, 1)                 21
#
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#Model optimization: SGD and Adam
sgd = tf.keras.optimizers.SGD(learning_rate=0.01, decay=0.0, momentum=0.7, nesterov=False)
adam=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8)
model.compile(optimizer=sgd, loss='mean_absolute_error')

# %%
# fit the keras model on the dataset
history = model.fit(X, y, epochs=100, batch_size=4, verbose=2, validation_split=0.20)
# Out:
# Epoch 1/100
# 19/19 - 0s - loss: 0.0828 - val_loss: 0.6594 - 365ms/epoch - 19ms/step
# Epoch 2/100
# 19/19 - 0s - loss: 0.0834 - val_loss: 0.6568 - 74ms/epoch - 4ms/step
# Epoch 3/100
# 19/19 - 0s - loss: 0.0820 - val_loss: 0.6573 - 57ms/epoch - 3ms/step
# Epoch 4/100
# 19/19 - 0s - loss: 0.0830 - val_loss: 0.6590 - 56ms/epoch - 3ms/step
# Epoch 5/100
# 19/19 - 0s - loss: 0.0778 - val_loss: 0.6440 - 57ms/epoch - 3ms/step
# Epoch 6/100
# 19/19 - 0s - loss: 0.0760 - val_loss: 0.6291 - 57ms/epoch - 3ms/step
# Epoch 7/100
# 19/19 - 0s - loss: 0.0755 - val_loss: 0.6446 - 56ms/epoch - 3ms/step
# Epoch 8/100
# 19/19 - 0s - loss: 0.0760 - val_loss: 0.6128 - 54ms/epoch - 3ms/step
# Epoch 9/100
# 19/19 - 0s - loss: 0.0756 - val_loss: 0.6252 - 73ms/epoch - 4ms/step
# Epoch 10/100
# 19/19 - 0s - loss: 0.0714 - val_loss: 0.6214 - 56ms/epoch - 3ms/step
# Epoch 11/100
# 19/19 - 0s - loss: 0.0728 - val_loss: 0.5930 - 60ms/epoch - 3ms/step
# Epoch 12/100
# 19/19 - 0s - loss: 0.0715 - val_loss: 0.5793 - 57ms/epoch - 3ms/step
# Epoch 13/100
# 19/19 - 0s - loss: 0.0710 - val_loss: 0.5706 - 72ms/epoch - 4ms/step
# Epoch 14/100
# 19/19 - 0s - loss: 0.0669 - val_loss: 0.5012 - 65ms/epoch - 3ms/step
# Epoch 15/100
# 19/19 - 0s - loss: 0.0742 - val_loss: 0.5395 - 56ms/epoch - 3ms/step
# Epoch 16/100
# 19/19 - 0s - loss: 0.0674 - val_loss: 0.5383 - 57ms/epoch - 3ms/step
# Epoch 17/100
# 19/19 - 0s - loss: 0.0658 - val_loss: 0.5190 - 57ms/epoch - 3ms/step
# Epoch 18/100
# 19/19 - 0s - loss: 0.0656 - val_loss: 0.5087 - 72ms/epoch - 4ms/step
# Epoch 19/100
# 19/19 - 0s - loss: 0.0642 - val_loss: 0.4978 - 52ms/epoch - 3ms/step
# Epoch 20/100
# 19/19 - 0s - loss: 0.0643 - val_loss: 0.5186 - 64ms/epoch - 3ms/step
# Epoch 21/100
# 19/19 - 0s - loss: 0.0626 - val_loss: 0.4925 - 69ms/epoch - 4ms/step
# Epoch 22/100
# 19/19 - 0s - loss: 0.0601 - val_loss: 0.5087 - 56ms/epoch - 3ms/step
# Epoch 23/100
# 19/19 - 0s - loss: 0.0563 - val_loss: 0.4818 - 57ms/epoch - 3ms/step
# Epoch 24/100
# 19/19 - 0s - loss: 0.0565 - val_loss: 0.4765 - 56ms/epoch - 3ms/step
# Epoch 25/100
# 19/19 - 0s - loss: 0.0579 - val_loss: 0.4852 - 56ms/epoch - 3ms/step
# Epoch 26/100
# 19/19 - 0s - loss: 0.0587 - val_loss: 0.4315 - 60ms/epoch - 3ms/step
# Epoch 27/100
# 19/19 - 0s - loss: 0.0498 - val_loss: 0.4427 - 56ms/epoch - 3ms/step
# Epoch 28/100
# 19/19 - 0s - loss: 0.0478 - val_loss: 0.4270 - 64ms/epoch - 3ms/step
# Epoch 29/100
# 19/19 - 0s - loss: 0.0476 - val_loss: 0.3988 - 56ms/epoch - 3ms/step
# Epoch 30/100
# 19/19 - 0s - loss: 0.0463 - val_loss: 0.4150 - 61ms/epoch - 3ms/step
# Epoch 31/100
# 19/19 - 0s - loss: 0.0481 - val_loss: 0.3576 - 56ms/epoch - 3ms/step
# Epoch 32/100
# 19/19 - 0s - loss: 0.0470 - val_loss: 0.3857 - 64ms/epoch - 3ms/step
# Epoch 33/100
# 19/19 - 0s - loss: 0.0481 - val_loss: 0.3482 - 56ms/epoch - 3ms/step
# Epoch 34/100
# 19/19 - 0s - loss: 0.0450 - val_loss: 0.3676 - 56ms/epoch - 3ms/step
# Epoch 35/100
# 19/19 - 0s - loss: 0.0379 - val_loss: 0.3375 - 57ms/epoch - 3ms/step
# Epoch 36/100
# 19/19 - 0s - loss: 0.0397 - val_loss: 0.3045 - 65ms/epoch - 3ms/step
# Epoch 37/100
# 19/19 - 0s - loss: 0.0375 - val_loss: 0.3123 - 57ms/epoch - 3ms/step
# Epoch 38/100
# 19/19 - 0s - loss: 0.0364 - val_loss: 0.2911 - 74ms/epoch - 4ms/step
# Epoch 39/100
# 19/19 - 0s - loss: 0.0339 - val_loss: 0.2321 - 65ms/epoch - 3ms/step
# Epoch 40/100
# 19/19 - 0s - loss: 0.0357 - val_loss: 0.2424 - 57ms/epoch - 3ms/step
# Epoch 41/100
# 19/19 - 0s - loss: 0.0328 - val_loss: 0.2680 - 56ms/epoch - 3ms/step
# Epoch 42/100
# 19/19 - 0s - loss: 0.0319 - val_loss: 0.2250 - 56ms/epoch - 3ms/step
# Epoch 43/100
# 19/19 - 0s - loss: 0.0299 - val_loss: 0.2009 - 56ms/epoch - 3ms/step
# Epoch 44/100
# 19/19 - 0s - loss: 0.0325 - val_loss: 0.2360 - 58ms/epoch - 3ms/step
# Epoch 45/100
# 19/19 - 0s - loss: 0.0294 - val_loss: 0.2150 - 56ms/epoch - 3ms/step
# Epoch 46/100
# 19/19 - 0s - loss: 0.0285 - val_loss: 0.1943 - 88ms/epoch - 5ms/step
# Epoch 47/100
# 19/19 - 0s - loss: 0.0300 - val_loss: 0.2176 - 56ms/epoch - 3ms/step
# Epoch 48/100
# 19/19 - 0s - loss: 0.0293 - val_loss: 0.1569 - 52ms/epoch - 3ms/step
# Epoch 49/100
# 19/19 - 0s - loss: 0.0295 - val_loss: 0.1245 - 59ms/epoch - 3ms/step
# Epoch 50/100
# 19/19 - 0s - loss: 0.0331 - val_loss: 0.1902 - 56ms/epoch - 3ms/step
# Epoch 51/100
# 19/19 - 0s - loss: 0.0261 - val_loss: 0.2189 - 48ms/epoch - 3ms/step
# Epoch 52/100
# 19/19 - 0s - loss: 0.0260 - val_loss: 0.1806 - 56ms/epoch - 3ms/step
# Epoch 53/100
# 19/19 - 0s - loss: 0.0239 - val_loss: 0.1347 - 56ms/epoch - 3ms/step
# Epoch 54/100
# 19/19 - 0s - loss: 0.0214 - val_loss: 0.1498 - 65ms/epoch - 3ms/step
# Epoch 55/100
# 19/19 - 0s - loss: 0.0264 - val_loss: 0.1311 - 59ms/epoch - 3ms/step
# Epoch 56/100
# 19/19 - 0s - loss: 0.0321 - val_loss: 0.1221 - 56ms/epoch - 3ms/step
# Epoch 57/100
# 19/19 - 0s - loss: 0.0229 - val_loss: 0.1315 - 61ms/epoch - 3ms/step
# Epoch 58/100
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.0813 - 57ms/epoch - 3ms/step
# Epoch 59/100
# 19/19 - 0s - loss: 0.0245 - val_loss: 0.1166 - 64ms/epoch - 3ms/step
# Epoch 60/100
# 19/19 - 0s - loss: 0.0208 - val_loss: 0.0927 - 49ms/epoch - 3ms/step
# Epoch 61/100
# 19/19 - 0s - loss: 0.0221 - val_loss: 0.1151 - 49ms/epoch - 3ms/step
# Epoch 62/100
# 19/19 - 0s - loss: 0.0227 - val_loss: 0.1342 - 56ms/epoch - 3ms/step
# Epoch 63/100
# 19/19 - 0s - loss: 0.0215 - val_loss: 0.0972 - 61ms/epoch - 3ms/step
# Epoch 64/100
# 19/19 - 0s - loss: 0.0249 - val_loss: 0.1353 - 48ms/epoch - 3ms/step
# Epoch 65/100
# 19/19 - 0s - loss: 0.0195 - val_loss: 0.1370 - 64ms/epoch - 3ms/step
# Epoch 66/100
# 19/19 - 0s - loss: 0.0193 - val_loss: 0.0776 - 49ms/epoch - 3ms/step
# Epoch 67/100
# 19/19 - 0s - loss: 0.0196 - val_loss: 0.0610 - 49ms/epoch - 3ms/step
# Epoch 68/100
# 19/19 - 0s - loss: 0.0230 - val_loss: 0.0683 - 58ms/epoch - 3ms/step
# Epoch 69/100
# 19/19 - 0s - loss: 0.0178 - val_loss: 0.0506 - 66ms/epoch - 3ms/step
# Epoch 70/100
# 19/19 - 0s - loss: 0.0226 - val_loss: 0.0438 - 56ms/epoch - 3ms/step
# Epoch 71/100
# 19/19 - 0s - loss: 0.0172 - val_loss: 0.0766 - 49ms/epoch - 3ms/step
# Epoch 72/100
# 19/19 - 0s - loss: 0.0223 - val_loss: 0.0502 - 49ms/epoch - 3ms/step
# Epoch 73/100
# 19/19 - 0s - loss: 0.0191 - val_loss: 0.0656 - 65ms/epoch - 3ms/step
# Epoch 74/100
# 19/19 - 0s - loss: 0.0155 - val_loss: 0.0804 - 65ms/epoch - 3ms/step
# Epoch 75/100
# 19/19 - 0s - loss: 0.0184 - val_loss: 0.0368 - 48ms/epoch - 3ms/step
# Epoch 76/100
# 19/19 - 0s - loss: 0.0189 - val_loss: 0.0506 - 64ms/epoch - 3ms/step
# Epoch 77/100
# 19/19 - 0s - loss: 0.0140 - val_loss: 0.0422 - 49ms/epoch - 3ms/step
# Epoch 78/100
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0379 - 59ms/epoch - 3ms/step
# Epoch 79/100
# 19/19 - 0s - loss: 0.0185 - val_loss: 0.0328 - 56ms/epoch - 3ms/step
# Epoch 80/100
# 19/19 - 0s - loss: 0.0147 - val_loss: 0.0346 - 60ms/epoch - 3ms/step
# Epoch 81/100
# 19/19 - 0s - loss: 0.0168 - val_loss: 0.0387 - 49ms/epoch - 3ms/step
# Epoch 82/100
# 19/19 - 0s - loss: 0.0158 - val_loss: 0.0272 - 58ms/epoch - 3ms/step
# Epoch 83/100
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0299 - 56ms/epoch - 3ms/step
# Epoch 84/100
# 19/19 - 0s - loss: 0.0183 - val_loss: 0.0305 - 64ms/epoch - 3ms/step
# Epoch 85/100
# 19/19 - 0s - loss: 0.0198 - val_loss: 0.0295 - 56ms/epoch - 3ms/step
# Epoch 86/100
# 19/19 - 0s - loss: 0.0145 - val_loss: 0.0435 - 57ms/epoch - 3ms/step
# Epoch 87/100
# 19/19 - 0s - loss: 0.0130 - val_loss: 0.0403 - 51ms/epoch - 3ms/step
# Epoch 88/100
# 19/19 - 0s - loss: 0.0126 - val_loss: 0.0368 - 49ms/epoch - 3ms/step
# Epoch 89/100
# 19/19 - 0s - loss: 0.0163 - val_loss: 0.0565 - 48ms/epoch - 3ms/step
# Epoch 90/100
# 19/19 - 0s - loss: 0.0150 - val_loss: 0.0371 - 57ms/epoch - 3ms/step
# Epoch 91/100
# 19/19 - 0s - loss: 0.0192 - val_loss: 0.0372 - 64ms/epoch - 3ms/step
# Epoch 92/100
# 19/19 - 0s - loss: 0.0151 - val_loss: 0.0372 - 49ms/epoch - 3ms/step
# Epoch 93/100
# 19/19 - 0s - loss: 0.0116 - val_loss: 0.0408 - 56ms/epoch - 3ms/step
# Epoch 94/100
# 19/19 - 0s - loss: 0.0143 - val_loss: 0.0408 - 56ms/epoch - 3ms/step
# Epoch 95/100
# 19/19 - 0s - loss: 0.0154 - val_loss: 0.0430 - 57ms/epoch - 3ms/step
# Epoch 96/100
# 19/19 - 0s - loss: 0.0127 - val_loss: 0.0403 - 56ms/epoch - 3ms/step
# Epoch 97/100
# 19/19 - 0s - loss: 0.0174 - val_loss: 0.0386 - 56ms/epoch - 3ms/step
# Epoch 98/100
# 19/19 - 0s - loss: 0.0179 - val_loss: 0.0890 - 61ms/epoch - 3ms/step
# Epoch 99/100
# 19/19 - 0s - loss: 0.0197 - val_loss: 0.0388 - 56ms/epoch - 3ms/step
# Epoch 100/100
# 19/19 - 0s - loss: 0.0114 - val_loss: 0.0460 - 64ms/epoch - 3ms/step

# %%
# evaluate on test set
yhat = model.predict(X)
error = mean_absolute_error(y, yhat)
print('MAE: %.5f' % error)
# Out:
# MAE: 0.01654

# %%
# Print the optimized output
print(yhat)
# Out:
# [[ 1.18589075e-02]
#  [ 8.18634778e-03]
#  [ 4.65114927e-03]
#  [ 5.97023498e-03]
#  [ 7.21881958e-03]
#  [ 1.12157622e-02]
#  [ 1.03152338e-02]
#  [ 6.67483127e-03]
#  [ 4.78100497e-03]
#  [ 4.92066238e-03]
#  [ 6.59370050e-03]
#  [ 8.59297160e-03]
#  [ 4.10497375e-03]
#  [ 5.33713959e-03]
#  [ 5.50358370e-03]
#  [ 2.08596047e-03]
#  [ 3.12838703e-03]
#  [-2.54376419e-03]
#  [ 4.39718366e-04]
#  [ 1.38082169e-03]
#  [-2.36506760e-03]
#  [-7.73892552e-03]
#  [ 5.21276565e-03]
#  [ 1.07069807e-02]
#  [ 3.82031314e-03]
#  [ 5.98521437e-03]
#  [-1.52621418e-04]
#  [-5.97964227e-03]
#  [ 2.51300633e-03]
#  [ 3.95005569e-04]
#  [ 1.44974701e-03]
#  [-2.30686553e-03]
#  [ 4.11043037e-03]
#  [ 1.01967454e-02]
#  [ 1.39459744e-02]
#  [ 1.75241418e-02]
#  [ 3.45898513e-03]
#  [ 8.08077678e-03]
#  [ 8.36919528e-03]
#  [ 4.67193499e-03]
#  [ 1.19323973e-02]
#  [ 1.41927823e-02]
#  [ 2.41110362e-02]
#  [ 1.20098777e-02]
#  [ 1.91757977e-02]
#  [ 2.02237908e-02]
#  [ 2.26215031e-02]
#  [ 2.14989595e-02]
#  [ 3.32104936e-02]
#  [ 3.51741016e-02]
#  [ 4.32489365e-02]
#  [ 5.06558083e-02]
#  [ 6.36380464e-02]
#  [ 6.49122000e-02]
#  [ 8.64724815e-02]
#  [ 1.00806624e-01]
#  [ 1.17646739e-01]
#  [ 1.34507075e-01]
#  [ 1.47831291e-01]
#  [ 1.47144690e-01]
#  [ 1.58376232e-01]
#  [ 1.80058390e-01]
#  [ 2.23684162e-01]
#  [ 2.41580009e-01]
#  [ 2.31808931e-01]
#  [ 2.82970220e-01]
#  [ 3.00126523e-01]
#  [ 3.21449161e-01]
#  [ 3.33852828e-01]
#  [ 3.72786343e-01]
#  [ 3.81109774e-01]
#  [ 4.04699385e-01]
#  [ 4.12701219e-01]
#  [ 4.12115574e-01]
#  [ 4.88008440e-01]
#  [ 4.96180058e-01]
#  [ 5.12012124e-01]
#  [ 5.33367515e-01]
#  [ 5.77984929e-01]
#  [ 5.92120409e-01]
#  [ 6.03555620e-01]
#  [ 6.07348919e-01]
#  [ 6.66172564e-01]
#  [ 6.81573808e-01]
#  [ 6.68309927e-01]
#  [ 7.18649089e-01]
#  [ 7.30881214e-01]
#  [ 7.53620267e-01]
#  [ 8.08755934e-01]
#  [ 8.16388011e-01]
#  [ 8.08004498e-01]
#  [ 8.68260205e-01]
#  [ 8.74052107e-01]
#  [ 8.88463080e-01]]

# %%
#print(y)

# %%
plt.plot(y)
plt.xlabel('Time (Day)')
plt.ylabel('Crop Yield')
plt.title('Mechanistic model: Crop Yield')
plt.show()

# %%
# plot the optimized output
plt.plot(yhat*1000)
plt.xlabel('Time (Day)')
plt.ylabel('Crop Yield')
plt.title('MLP model: Crop Yield')
plt.show()
